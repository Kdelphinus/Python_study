# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data/subway.csv')
df.head()
# Out:
#   line station    in   out
# 0  중앙선      지평    37    28
# 1  중앙선      용문  2064  2103
# 2  중앙선      원덕   375   357
# 3  중앙선      양평  4338  4378
# 4  중앙선      오빈   321   321

# %%
sns.kdeplot(df['in'])
# Out:
# <AxesSubplot:xlabel='in', ylabel='Density'>
