# %%
import pandas as pd

# %%
df = pd.read_csv('data/sports.csv', index_col = 0)
df
# Out:
#             Male  Female
# Swimming     103     178
# Baseball     363     289
# Basketball   151      97
# Golf         154     232
# Soccer       413     109
# Bowling       88     129

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind ='bar')  # 막대 그래프는 bar
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'barh') # 가로로 넘길 땐 h 추가
# Out:
# <AxesSubplot:>

# %%
df.plot(kind ='bar', stacked = True) # stacked는 쌓아서 볼 것인지
# Out:
# <AxesSubplot:>

# %%
df['Female']
# Out:
# Swimming      178
# Baseball      289
# Basketball     97
# Golf          232
# Soccer        109
# Bowling       129
# Name: Female, dtype: int64

# %%
 df['Female'].plot(kind='bar',color=['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown'])
# Out:
# <AxesSubplot:>
