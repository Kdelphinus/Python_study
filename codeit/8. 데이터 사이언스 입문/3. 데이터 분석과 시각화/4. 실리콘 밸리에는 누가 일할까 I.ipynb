# %%
import pandas as pd

# %%
df = pd.read_csv('data/silicon_valley_summary.csv')

# %%
boolean_male = df['gender']=='Male'
boolean_manager = df['job_category'] == 'Managers'
boolean_not_all = df['race_ethnicity'] != 'All'

condition = boolean_male & boolean_manager & boolean_not_all

# %%
df[condition].plot(kind='bar', x='race_ethnicity',  y='count')
# Out:
# <AxesSubplot:xlabel='race_ethnicity'>
