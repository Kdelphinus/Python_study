# %%
# %matplotlib inline

import pandas as pd

# %%
df = pd.read_csv('data/broadcast.csv', index_col = 0)
df
# Out:
#          KBS     MBC     SBS  TV CHOSUN   JTBC  Channel A    MBN
# 2011  35.951  18.374  11.173      9.102  7.380      3.771  2.809
# 2012  36.163  16.022  11.408      8.785  7.878      5.874  3.310
# 2013  31.989  16.778   9.673      9.026  7.810      5.350  3.825
# 2014  31.210  15.663   9.108      9.440  7.490      5.776  4.572
# 2015  27.777  16.573   9.099      9.940  7.267      6.678  5.520
# 2016  27.583  14.982   8.669      9.829  7.727      6.624  5.477
# 2017  26.890  12.465   8.661      8.886  9.453      6.056  5.215

# %%
df.plot() # 괄호 안에 kind=line을 넘겨야 하지만 line 그래프가 기본이라 안넘겨도 됨
# Out:
# <AxesSubplot:>

# %%
df.plot(y = 'KBS')
# Out:
# <AxesSubplot:>

# %%
df.plot(y = ['SBS', 'JTBC'])
# Out:
# <AxesSubplot:>

# %%
df[['KBS', 'JTBC']]
# Out:
#          KBS   JTBC
# 2011  35.951  7.380
# 2012  36.163  7.878
# 2013  31.989  7.810
# 2014  31.210  7.490
# 2015  27.777  7.267
# 2016  27.583  7.727
# 2017  26.890  9.453

# %%
df[['KBS', 'JTBC']].plot()
# Out:
# <AxesSubplot:>

# %%
df['KBS']
# Out:
# 2011    35.951
# 2012    36.163
# 2013    31.989
# 2014    31.210
# 2015    27.777
# 2016    27.583
# 2017    26.890
# Name: KBS, dtype: float64

# %%
df['KBS'].plot()
# Out:
# <AxesSubplot:>
